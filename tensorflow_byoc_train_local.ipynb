# %% [markdown]
# # Amazon SageMaker - Bring Your Own Container¶
# ### ノートブックインスタンスでのローカル学習
# ここでは TensorFlow を使ったサンプルコードを題材に、Amazon SageMaker で独自コンテナを用いた機械学習モデルの学習方法を順を追って説明します。今回はデバックに最適なノートブックインスタンス上での学習を取り扱います。トレーニングスクリプトは既に SageMaker 向けに書き換えられた形で準備され、その上で、独自の学習用コンテナを活用します。 トレーニングスクリプトを SageMaker 向けに書き換える際は [Bring Your Own Model ハンズオンワークショップ](https://github.com/aws-samples/amazon-sagemaker-examples-jp/tree/master/workshop/lab_bring-your-own-model) をご参考に下さい。
#
# また本ハンズオンで活用するデータは、[Bring Your Own Container のためのデータ準備](https://github.com/tkazusa/data_prep.ipynb)をお使い下さい。

# %%
import keras

import boto3
import sagemaker
from sagemaker import get_execution_role
from sagemaker.estimator import Estimator

sess = sagemaker.Session()
bucket = '20200222-tensorflow-byoc'

# %%
# !docker build -t sm-tf-nightly-gpu container/.
# Out:
# Sending build context to Docker daemon  10.24kB
# Step 1/4 : FROM tensorflow/tensorflow:nightly-gpu
#  ---> ad7cd4026486
# Step 2/4 : RUN pip install sagemaker-containers
#  ---> Using cache
#  ---> 28545073ce2f
# Step 3/4 : COPY tf_codes /opt/ml/code/
#  ---> 40264b5f3980
# Step 4/4 : ENV SAGEMAKER_PROGRAM train.py
#  ---> Running in 066c76f93052
# Removing intermediate container 066c76f93052
#  ---> 8443b5663baa
# Successfully built 8443b5663baa
# Successfully tagged sm-tf-nightly-gpu:latest

# %% [markdown]
# ## Jupyter notebook のインスタンスを用いた学習の確認

# %%
sagemaker_session = sagemaker.Session()
role = get_execution_role()

estimator = Estimator(image_name='sm-tf-nightly-gpu',
                      role=role,
                      hyperparameters={'batch_size': 64,'epochs': 1},
                      train_instance_count=1,
                      train_instance_type='local_gpu')

estimator.fit({'train': 'file://data'})
# Out:
# Creating tmpexa7alak_algo-1-iwwgw_1 ...
# Attaching to tmpexa7alak_algo-1-iwwgw_12mdone
# algo-1-iwwgw_1  | 2020-02-22 14:28:25,197 sagemaker-containers INFO     Invoking user script
# algo-1-iwwgw_1  |
# algo-1-iwwgw_1  | Training Env:
# algo-1-iwwgw_1  |
# algo-1-iwwgw_1  | {
# algo-1-iwwgw_1  |     "additional_framework_parameters": {},
# algo-1-iwwgw_1  |     "channel_input_dirs": {
# algo-1-iwwgw_1  |         "train": "/opt/ml/input/data/train"
# algo-1-iwwgw_1  |     },
# algo-1-iwwgw_1  |     "current_host": "algo-1-iwwgw",
# algo-1-iwwgw_1  |     "framework_module": null,
# algo-1-iwwgw_1  |     "hosts": [
# algo-1-iwwgw_1  |         "algo-1-iwwgw"
# algo-1-iwwgw_1  |     ],
# algo-1-iwwgw_1  |     "hyperparameters": {
# algo-1-iwwgw_1  |         "batch_size": 64,
# algo-1-iwwgw_1  |         "epochs": 1
# algo-1-iwwgw_1  |     },
# algo-1-iwwgw_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-iwwgw_1  |     "input_data_config": {
# algo-1-iwwgw_1  |         "train": {
# algo-1-iwwgw_1  |             "TrainingInputMode": "File"
# algo-1-iwwgw_1  |         }
# algo-1-iwwgw_1  |     },
# algo-1-iwwgw_1  |     "input_dir": "/opt/ml/input",
# algo-1-iwwgw_1  |     "is_master": true,
# algo-1-iwwgw_1  |     "job_name": "sm-tf-nightly-gpu-2020-02-22-14-28-22-930",
# algo-1-iwwgw_1  |     "log_level": 20,
# algo-1-iwwgw_1  |     "master_hostname": "algo-1-iwwgw",
# algo-1-iwwgw_1  |     "model_dir": "/opt/ml/model",
# algo-1-iwwgw_1  |     "module_dir": "/opt/ml/code",
# algo-1-iwwgw_1  |     "module_name": "train",
# algo-1-iwwgw_1  |     "network_interface_name": "eth0",
# algo-1-iwwgw_1  |     "num_cpus": 4,
# algo-1-iwwgw_1  |     "num_gpus": 1,
# algo-1-iwwgw_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-iwwgw_1  |     "output_dir": "/opt/ml/output",
# algo-1-iwwgw_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-iwwgw_1  |     "resource_config": {
# algo-1-iwwgw_1  |         "current_host": "algo-1-iwwgw",
# algo-1-iwwgw_1  |         "hosts": [
# algo-1-iwwgw_1  |             "algo-1-iwwgw"
# algo-1-iwwgw_1  |         ]
# algo-1-iwwgw_1  |     },
# algo-1-iwwgw_1  |     "user_entry_point": "train.py"
# algo-1-iwwgw_1  | }
# algo-1-iwwgw_1  |
# algo-1-iwwgw_1  | Environment variables:
# algo-1-iwwgw_1  |
# algo-1-iwwgw_1  | SM_HOSTS=["algo-1-iwwgw"]
# algo-1-iwwgw_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-iwwgw_1  | SM_HPS={"batch_size":64,"epochs":1}
# algo-1-iwwgw_1  | SM_USER_ENTRY_POINT=train.py
# algo-1-iwwgw_1  | SM_FRAMEWORK_PARAMS={}
# algo-1-iwwgw_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-iwwgw","hosts":["algo-1-iwwgw"]}
# algo-1-iwwgw_1  | SM_INPUT_DATA_CONFIG={"train":{"TrainingInputMode":"File"}}
# algo-1-iwwgw_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-iwwgw_1  | SM_CHANNELS=["train"]
# algo-1-iwwgw_1  | SM_CURRENT_HOST=algo-1-iwwgw
# algo-1-iwwgw_1  | SM_MODULE_NAME=train
# algo-1-iwwgw_1  | SM_LOG_LEVEL=20
# algo-1-iwwgw_1  | SM_FRAMEWORK_MODULE=
# algo-1-iwwgw_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-iwwgw_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-iwwgw_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-iwwgw_1  | SM_NUM_CPUS=4
# algo-1-iwwgw_1  | SM_NUM_GPUS=1
# algo-1-iwwgw_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-iwwgw_1  | SM_MODULE_DIR=/opt/ml/code
# algo-1-iwwgw_1  | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1-iwwgw","framework_module":null,"hosts":["algo-1-iwwgw"],"hyperparameters":{"batch_size":64,"epochs":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sm-tf-nightly-gpu-2020-02-22-14-28-22-930","log_level":20,"master_hostname":"algo-1-iwwgw","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-iwwgw","hosts":["algo-1-iwwgw"]},"user_entry_point":"train.py"}
# algo-1-iwwgw_1  | SM_USER_ARGS=["--batch_size","64","--epochs","1"]
# algo-1-iwwgw_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-iwwgw_1  | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# algo-1-iwwgw_1  | SM_HP_BATCH_SIZE=64
# algo-1-iwwgw_1  | SM_HP_EPOCHS=1
# algo-1-iwwgw_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-iwwgw_1  |
# algo-1-iwwgw_1  | Invoking script with the following command:
# algo-1-iwwgw_1  |
# algo-1-iwwgw_1  | /usr/bin/python3 train.py --batch_size 64 --epochs 1
# algo-1-iwwgw_1  |
# algo-1-iwwgw_1  |
# algo-1-iwwgw_1  | 3.6.9 (default, Nov  7 2019, 10:44:02)
# algo-1-iwwgw_1  | [GCC 8.3.0]
# algo-1-iwwgw_1  | [{'index': '0', 'uuid': 'GPU-c37bd772-d57f-93d7-314e-678e020fc76a', 'name': 'Tesla K80', 'timestamp': '2020/02/22 14:28:26.872', 'memory.total': '11441', 'memory.free': '11441', 'memory.used': '0', 'utilization.gpu': '0', 'utilization.memory': '0'}]
# algo-1-iwwgw_1  | 2020-02-22 14:28:26.993661: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.015279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.016177: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1558] Found device 0 with properties:
# algo-1-iwwgw_1  | pciBusID: 0000:00:1e.0 name: Tesla K80 computeCapability: 3.7
# algo-1-iwwgw_1  | coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.016469: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.018458: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.020324: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.020650: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.022671: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.023903: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.028223: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.028370: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.029264: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.030046: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Adding visible gpu devices: 0
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.030457: I tensorflow/core/platform/cpu_feature_guard.cc:143] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.060289: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300065000 Hz
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.060741: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3799c80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.060887: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.116009: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.116937: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3f6b2e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.116965: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.117185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.118020: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1558] Found device 0 with properties:
# algo-1-iwwgw_1  | pciBusID: 0000:00:1e.0 name: Tesla K80 computeCapability: 3.7
# algo-1-iwwgw_1  | coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.118088: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.118122: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.118149: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.118172: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.118196: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.118223: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.118253: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.118341: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.119207: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.120043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Adding visible gpu devices: 0
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.120111: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.121556: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1099] Device interconnect StreamExecutor with strength 1 edge matrix:
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.121583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1105]      0
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.121600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1118] 0:   N
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.121749: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.122593: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# algo-1-iwwgw_1  | 2020-02-22 14:28:27.123402: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1244] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:1e.0, compute capability: 3.7)
# algo-1-iwwgw_1  | Train on 60000 samples
# algo-1-iwwgw_1  | 2020-02-22 14:28:28.222343: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 3.1067 - accuracy: 0.7546
# 10000/10000 [==============================] - 1s 66us/sample - loss: 0.6127 - accuracy: 0.8522
# algo-1-iwwgw_1  | 2020-02-22 14:28:31,787 sagemaker-containers INFO     Reporting training SUCCESS
# tmpexa7alak_algo-1-iwwgw_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====
